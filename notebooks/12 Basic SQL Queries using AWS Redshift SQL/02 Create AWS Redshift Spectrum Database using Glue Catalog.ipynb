# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://admin:Itversity123@retail-wg.269066542444.us-east-1.redshift-serverless.amazonaws.com:5439/dev
# Out:
# env: DATABASE_URL=postgresql://admin:Itversity123@retail-wg.269066542444.us-east-1.redshift-serverless.amazonaws.com:5439/dev

# %%
# %%sql
#
# SELECT * FROM information_schema.tables;
# Out:
#  * postgresql://admin:***@retail-wg.269066542444.us-east-1.redshift-serverless.amazonaws.com:5439/dev
# 147 rows affected.
# [('dev', 'pg_internal', 'redshift_auto_health_check_12903534', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_default_acl', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_conf', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_library', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_shdepend', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statistic_indicator', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_external_schema', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statistic', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_attribute', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_class', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_tablespace', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_inherits', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_index', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_operator', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_opclass', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_am', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_amop', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_amproc', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_language', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_largeobject', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_aggregate', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statistic_multicol', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_trigger', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_listener', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_cast', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_namespace', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_conversion', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_udf', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_bar_repos', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_bar_state', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_depend', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_highwatermark', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_resize', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_attrdef', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_constraint', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_database', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_description', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_group', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_proc', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_rewrite', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_bar_ddllog', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_user', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_rules', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_views', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_table_def', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stats', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_all_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_sys_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_user_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_all_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_sys_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_user_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_all_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_sys_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_user_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_all_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_sys_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_user_indexes', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_all_sequences', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_sys_sequences', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_statio_user_sequences', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_activity', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_stat_database', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_locks', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_test', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'systable_globaldict', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'padb_config_harvest', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'systable_schema', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'systable_topology', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_datashares', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_datashare_objects', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_datashare_consumers', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_external_columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_external_databases', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_external_partitions', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_external_schemas', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_external_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_redshift_columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_redshift_databases', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_redshift_functions', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_redshift_schemas', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_redshift_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_all_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_all_columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_all_schemas', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_table_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'svv_transactions', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_query_detail', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_external_query_detail', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_load_history', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_load_error_detail', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_unload_history', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_serverless_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'sys_query_history', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_user_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_database_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_class_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_proc_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'pg_catalog', 'pg_attribute_info', 'VIEW', None, None, None, None, None),
#  ('dev', 'public', 'my_first_dbt_model', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'public', 'my_second_dbt_model', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'information_schema_catalog_name', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'applicable_roles', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'check_constraints', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'column_domain_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'column_privileges', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'column_udt_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'constraint_column_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'constraint_table_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'domain_constraints', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'domain_udt_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'domains', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'enabled_roles', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'key_column_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'parameters', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'referential_constraints', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'role_column_grants', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'role_routine_grants', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'role_table_grants', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'role_usage_grants', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'routine_privileges', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'routines', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'schemata', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_features', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_implementation_info', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_languages', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_packages', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_sizing', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'sql_sizing_profiles', 'BASE TABLE', None, None, None, None, None),
#  ('dev', 'information_schema', 'table_constraints', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'table_privileges', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'tables', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'triggered_update_columns', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'triggers', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'usage_privileges', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'view_column_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'view_table_usage', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'views', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'data_type_privileges', 'VIEW', None, None, None, None, None),
#  ('dev', 'information_schema', 'element_types', 'VIEW', None, None, None, None, None)]

# %%
# %%sql
#
# CREATE EXTERNAL SCHEMA IF NOT EXISTS retail_db
# FROM DATA CATALOG
# DATABASE 'retail_db'
# IAM_ROLE 'arn:aws:iam::269066542444:role/AIRedshiftRetailSpectrum'
# CREATE EXTERNAL DATABASE IF NOT EXISTS

# %%
# %%sql
#
# SELECT count(*) FROM retail_db.orders

# %%
# %%sql
#
# SELECT count(*) FROM retail_db.order_items
